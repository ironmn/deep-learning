# %%
# !pip install matplotlib
# %matplotlib inline
# !pip install numpy
import numpy as np
from matplotlib_inline import backend_inline
# !pip install d2l
from d2l import torch as d2l


def f(x):
    return 3*x ** 2 - 4 * x
# Out:
# Requirement already satisfied: matplotlib in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.20 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: six>=1.5 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: numpy in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (1.23.5)
# Requirement already satisfied: d2l in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (1.0.3)
# Requirement already satisfied: jupyter==1.0.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from d2l) (1.0.0)
# Requirement already satisfied: numpy==1.23.5 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from d2l) (1.23.5)
# Requirement already satisfied: matplotlib==3.7.2 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from d2l) (3.7.2)
# Requirement already satisfied: matplotlib-inline==0.1.6 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from d2l) (0.1.6)
# Requirement already satisfied: requests==2.31.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from d2l) (2.31.0)
# Requirement already satisfied: pandas==2.0.3 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from d2l) (2.0.3)
# Requirement already satisfied: scipy==1.10.1 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from d2l) (1.10.1)
# Requirement already satisfied: notebook in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyter==1.0.0->d2l) (7.4.0)
# Requirement already satisfied: qtconsole in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyter==1.0.0->d2l) (5.6.1)
# Requirement already satisfied: jupyter-console in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyter==1.0.0->d2l) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyter==1.0.0->d2l) (7.16.6)
# Requirement already satisfied: ipykernel in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyter==1.0.0->d2l) (6.29.5)
# Requirement already satisfied: ipywidgets in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyter==1.0.0->d2l) (8.1.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from matplotlib==3.7.2->d2l) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from matplotlib==3.7.2->d2l) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from matplotlib==3.7.2->d2l) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from matplotlib==3.7.2->d2l) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from matplotlib==3.7.2->d2l) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from matplotlib==3.7.2->d2l) (11.1.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from matplotlib==3.7.2->d2l) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from matplotlib==3.7.2->d2l) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from matplotlib==3.7.2->d2l) (6.5.2)
# Requirement already satisfied: traitlets in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from matplotlib-inline==0.1.6->d2l) (5.14.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from pandas==2.0.3->d2l) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from pandas==2.0.3->d2l) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from requests==2.31.0->d2l) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from requests==2.31.0->d2l) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from requests==2.31.0->d2l) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from requests==2.31.0->d2l) (2025.1.31)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from importlib-resources>=3.2.0->matplotlib==3.7.2->d2l) (3.21.0)
# Requirement already satisfied: six>=1.5 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.7.2->d2l) (1.17.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l) (1.8.13)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l) (8.18.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l) (5.7.2)
# Requirement already satisfied: nest-asyncio in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l) (1.6.0)
# Requirement already satisfied: psutil in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l) (26.3.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l) (6.4.2)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from ipywidgets->jupyter==1.0.0->d2l) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.14 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from ipywidgets->jupyter==1.0.0->d2l) (3.0.14)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyter-console->jupyter==1.0.0->d2l) (3.0.50)
# Requirement already satisfied: pygments in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyter-console->jupyter==1.0.0->d2l) (2.19.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter==1.0.0->d2l) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l) (0.7.1)
# Requirement already satisfied: importlib-metadata>=3.6 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l) (8.6.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l) (3.1.6)
# Requirement already satisfied: jupyterlab-pygments in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l) (1.5.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from notebook->jupyter==1.0.0->d2l) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from notebook->jupyter==1.0.0->d2l) (2.27.3)
# Requirement already satisfied: jupyterlab<4.5,>=4.4.0rc0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from notebook->jupyter==1.0.0->d2l) (4.4.0)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from notebook->jupyter==1.0.0->d2l) (0.2.4)
# Requirement already satisfied: qtpy>=2.4.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from qtconsole->jupyter==1.0.0->d2l) (2.4.3)
# Requirement already satisfied: webencodings in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter==1.0.0->d2l) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter==1.0.0->d2l) (1.4.0)
# Requirement already satisfied: decorator in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.19.2)
# Requirement already satisfied: stack-data in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.6.3)
# Requirement already satisfied: typing-extensions in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (4.12.2)
# Requirement already satisfied: exceptiongroup in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (1.2.2)
# Requirement already satisfied: colorama in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.4.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter==1.0.0->d2l) (4.3.7)
# Requirement already satisfied: pywin32>=300 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter==1.0.0->d2l) (307)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (0.21.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (2.0.15)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyterlab<4.5,>=4.4.0rc0->notebook->jupyter==1.0.0->d2l) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyterlab<4.5,>=4.4.0rc0->notebook->jupyter==1.0.0->d2l) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyterlab<4.5,>=4.4.0rc0->notebook->jupyter==1.0.0->d2l) (2.2.5)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyterlab<4.5,>=4.4.0rc0->notebook->jupyter==1.0.0->d2l) (75.8.0)
# Requirement already satisfied: tomli>=1.2.2 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyterlab<4.5,>=4.4.0rc0->notebook->jupyter==1.0.0->d2l) (2.2.1)
# Requirement already satisfied: babel>=2.10 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->d2l) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->d2l) (0.12.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->d2l) (4.23.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter==1.0.0->d2l) (2.21.1)
# Requirement already satisfied: wcwidth in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter==1.0.0->d2l) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from beautifulsoup4->nbconvert->jupyter==1.0.0->d2l) (2.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (21.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.5,>=4.4.0rc0->notebook->jupyter==1.0.0->d2l) (1.0.8)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.5,>=4.4.0rc0->notebook->jupyter==1.0.0->d2l) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->d2l) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->d2l) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->d2l) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->d2l) (0.24.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (0.1.1)
# Requirement already satisfied: executing>=1.2.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.2.3)
# Requirement already satisfied: fqdn in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\lelou\anaconda3\envs\d2l\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (2.9.0.20241206)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 7
#       5 from matplotlib_inline import backend_inline
#       6 get_ipython().system('pip install d2l')
# ----> 7 from d2l import torch as d2l
#      10 def f(x):
#      11     return 3*x ** 2 - 4 * x
#
# File c:\Users\lelou\anaconda3\envs\d2l\lib\site-packages\d2l\torch.py:5
#       2 DATA_URL = 'http://d2l-data.s3-accelerate.amazonaws.com/'
#       4 import numpy as np
# ----> 5 import torch
#       6 import torchvision
#       7 from PIL import Image
#
# ModuleNotFoundError: No module named 'torch'

# %%
def numerical_lim(f, x, h):
    return (f(x + h) - f(x)) / h

h = 0.1
for i in range(5):
    print(f'h={h:.5f}, numerical limit={numerical_lim(f, 1, h):.5f}')
    h *= 0.1
# Out:
# h=0.10000, numerical limit=2.30000
# h=0.01000, numerical limit=2.03000
# h=0.00100, numerical limit=2.00300
# h=0.00010, numerical limit=2.00030
# h=0.00001, numerical limit=2.00003

# %%
def use_svg_display():  #@save
    """使用svg格式在Jupyter中显示绘图"""
    backend_inline.set_matplotlib_formats('svg')

# %%
def set_figsize(figsize=(3.5, 2.5)):  #@save
    """设置matplotlib的图表大小"""
    use_svg_display()
    d2l.plt.rcParams['figure.figsize'] = figsize

# %%
#@save
def set_axes(axes, xlabel, ylabel, xlim, ylim, xscale, yscale, legend):
    """设置matplotlib的轴"""
    axes.set_xlabel(xlabel)
    axes.set_ylabel(ylabel)
    axes.set_xscale(xscale)
    axes.set_yscale(yscale)
    axes.set_xlim(xlim)
    axes.set_ylim(ylim)
    if legend:
        axes.legend(legend)
    axes.grid()

# %%
#@save
def plot(X, Y=None, xlabel=None, ylabel=None, legend=None, xlim=None,
         ylim=None, xscale='linear', yscale='linear',
         fmts=('-', 'm--', 'g-.', 'r:'), figsize=(3.5, 2.5), axes=None):
    """绘制数据点"""
    if legend is None:
        legend = []

    set_figsize(figsize)
    axes = axes if axes else d2l.plt.gca()

    # 如果X有一个轴，输出True
    def has_one_axis(X):
        return (hasattr(X, "ndim") and X.ndim == 1 or isinstance(X, list)
                and not hasattr(X[0], "__len__"))

    if has_one_axis(X):
        X = [X]
    if Y is None:
        X, Y = [[]] * len(X), X
    elif has_one_axis(Y):
        Y = [Y]
    if len(X) != len(Y):
        X = X * len(Y)
    axes.cla()
    for x, y, fmt in zip(X, Y, fmts):
        if len(x):
            axes.plot(x, y, fmt)
        else:
            axes.plot(y, fmt)
    set_axes(axes, xlabel, ylabel, xlim, ylim, xscale, yscale, legend)

# %%
x = np.arange(0, 3, 0.1)
plot(x, [f(x), 2 * x - 3], 'x', 'f(x)', legend=['f(x)', 'Tangent line (x=1)'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 x = np.arange(0, 3, 0.1)
# ----> 2 plot(x, [f(x), 2 * x - 3], 'x', 'f(x)', legend=['f(x)', 'Tangent line (x=1)'])
#
# Cell In[12], line 9, in plot(X, Y, xlabel, ylabel, legend, xlim, ylim, xscale, yscale, fmts, figsize, axes)
#       6 if legend is None:
#       7     legend = []
# ----> 9 set_figsize(figsize)
#      10 axes = axes if axes else d2l.plt.gca()
#      12 # 如果X有一个轴，输出True
#
# Cell In[10], line 4, in set_figsize(figsize)
#       2 """设置matplotlib的图表大小"""
#       3 use_svg_display()
# ----> 4 d2l.plt.rcParams['figure.figsize'] = figsize
#
# NameError: name 'd2l' is not defined
